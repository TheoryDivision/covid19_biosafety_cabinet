# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(index = ['Coronavirus', 'Influenza A','Staphylococcus aureus','Mycoplasma spp.','Aspergillus flavus'],columns=['Integral Dose '])

# %%
df['Integral Dose'] = np.array([3200,1900,6600,8400,34900])

# %%
60000/200/60
# Out:
# 5.0

# %%
[i/np.arange(50,251,1)  for i in df['Integral Dose']];

# %%
fig,ax= plt.subplots(figsize=(10,6))
cols = ['Navy', 'Green','lightblue','Orange','purple']
for i,data in enumerate([i/np.arange(50,251,1)  for i in df['Integral Dose']][::-1]):
    ax.plot(np.arange(50,251,1),data/60,label=df.index[len(df.index)-1-i],lw=7,color=cols[i])
    
ax.legend(bbox_to_anchor=[1, 0.7],edgecolor='w',fontsize=12)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(1)
ax.spines['bottom'].set_linewidth(1)
#plt.yscale('log')
ax.tick_params(axis='both', which='major', labelsize=14)
ax.grid(color='lightgrey', linestyle='-', linewidth=2)
ax.set_ylabel('Time to 90% sterilization (min.)',fontsize=16)
ax.set_xlabel(r'UV intensity $(\mu W\,cm^{-2})$',fontsize=16)
plt.tight_layout()
plt.savefig('BSC_organisms.pdf')

# %%
xs = [1,2,3]
ys=[1,2,3]
states = ['on','off']
position = [1,2,3]

# %%
'h1_'+str(x)+str(y)+'_cent_all_'+str(state)
# Out:
# 'h1_22_cent_all_off'

# %%
data = []
for x in xs:
    for y in ys:
        for state in states:
            for pos in position:
                string='h1_'+str(x)+str(y)+'_cent_all_'+str(state)
                df=pd.read_csv('hood1/%s/uv_data%s.csv'% (string,str(pos)))
                data.append({'V':df.values.mean(),'x':x,'y':y,'state':state,'pos':pos})

# %%
df=pd.DataFrame(data)

# %%
for x in xs:
    for y in ys:
        df[df['x'] == x][df['y'] == x]
# Out:
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
delV = df[df['state']=='on']['V'].values - df[df['state']=='off']['V'].values
df= df[df['state']=='on']
df['delV'] = delV
df= df.drop(columns=['state'])

# %%
for
df['delV']
# Out:
# 0     0.036558
# 1     0.031683
# 2     0.026080
# 6     0.039145
# 7     0.032100
# 8     0.026468
# 12    0.042907
# 13    0.023563
# 14    0.018677
# 18    0.048837
# 19    0.041802
# 20    0.054818
# 24    0.130644
# 25    0.124224
# 26    0.111763
# 30    0.065246
# 31    0.046688
# 32    0.041235
# 36    0.013463
# 37    0.015274
# 38    0.029484
# 42    0.033782
# 43    0.024876
# 44    0.028200
# 48    0.026886
# 49    0.019414
# 50    0.018737
# Name: delV, dtype: float64

# %%
df.plot

# %%
plt.imshow(df[df['x'] == x][df['y'] == x]['V'])
# Out:
# /Users/nikhilkrishnan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-9f00b66c69e8> in <module>()
# ----> 1 plt.imshow(df[df['x'] == x][df['y'] == x]['V'])
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# ...

# %%
df1=pd.read_csv('hood1/uv_data1.csv')
df2=pd.read_csv('hood1/uv_data2.csv')
df3=pd.read_csv('hood1/uv_data3.csv')
fig,ax=plt.subplots()
df1.plot(ax=ax,label='1')
df2.plot(ax=ax,label='1')
df3.plot(ax=ax,label='1')
ax.legend()

# %%
df1_off=pd.read_csv('Archive/h1_cent_all_off/uv_data1.csv')
df2_off=pd.read_csv('Archive/h1_cent_all_off/uv_data2.csv')
df3_off=pd.read_csv('Archive/h1_cent_all_off/uv_data3.csv')
df1_on=pd.read_csv('Archive/h1_cent_all_on/uv_data1.csv')
df2_on=pd.read_csv('Archive/h1_cent_all_on/uv_data2.csv')
df3_on=pd.read_csv('Archive/h1_cent_all_on/uv_data3.csv')

# %%
V1= np.mean(df1_on.values)-np.mean(df1_off.values)
V2= np.mean(df2_on.values)-np.mean(df2_off.values)
V3= np.mean(df3_on.values)-np.mean(df3_off.values)

# %%
V3
# Out:
# 0.11176341074861905
